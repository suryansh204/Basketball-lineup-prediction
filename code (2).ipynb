# %%
library(tidyverse)
library(tidymodels)
library(GGally)

# %%
lineup_stat <- read_csv("https://raw.githubusercontent.com/JerryQi77/DSCI_Group-Project/main/DSCI_Group_project?token=GHSAT0AAAAAABZQJWZPOUAKKT7OY7UAZ33IY2546GQ")
lineup_stat
# Out:
# Rows: 250 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (6): TEAM, First Player, Second Player, Third Player, Fourth Player, Fi...
# dbl (24): ...1, GP, MIN, PTS, FGM, FGA, FG%, 3PM, 3PA, 3P%, FTM, FTA, FT%, O...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     ...1 TEAM GP MIN  PTS  FGM  FGA  FG%  3PM 3PA  ⋯ BLK BLKA PF  PFD +/-
# 1    0   ORL  19 21.6 52.3 20.4 42.3 48.2 4.3 10.9 ⋯ 2.2 2.4  8.0 6.9  0.8
# 2    1   MIN  41 21.5 46.3 17.6 37.2 47.4 3.2  9.1 ⋯ 2.0 2.2  7.8 8.9 -0.9
# 3    2   WAS  69 19.5 45.4 17.7 35.9 49.4 4.1 10.1 ⋯ 1.4 2.0  7.1 7.1  3.4
# 4    3   LAC  46 18.9 44.0 16.2 31.6 51.3 3.8  8.5 ⋯ 2.0 1.1  6.2 9.3  5.4
# 5    4   CLE  27 16.8 40.9 15.3 31.1 49.0 5.0 11.5 ⋯ 1.4 1.4  5.6 7.1  2.2
# 6    5   CHA  47 16.7 36.2 13.3 29.4 45.1 3.3  9.3 ⋯ 1.6 2.2  4.6 6.4  1.7
# 7    6   PHX   7 16.4 38.3 14.4 29.9 48.3 2.7  7.9 ⋯ 0.7 1.9  8.4 6.9  0.1
# 8    7   MIN  38 15.7 34.8 13.3 27.0 49.5 2.2  5.8 ⋯ 1.4 1.5  5.3 6.2  0.6
# 9    8   CLE  12 15.1 40.2 14.5 27.7 52.4 5.2 10.6 ⋯ 1.5 1.4  3.5 6.4  9.8
# 10   9   TOR  16 14.6 30.4 12.1 25.8 47.1 2.3  6.4 ⋯ 2.1 1.2  5.3 4.8  0.4
# 11  10   POR   6 14.5 31.7 11.5 25.3 45.4 2.5  6.2 ⋯ 0.7 1.7  6.3 5.7  0.5
# 12  11   LAL  28 14.4 32.3 12.2 26.5 46.1 3.8  9.0 ⋯ 0.7 1.3  5.8 4.6  1.6
# 13  12   NOP   7 14.2 32.0 12.0 26.9 44.7 3.9  9.4 ⋯ 1.7 1.3  3.1 5.3  1.7
# 14  13   NYK  28 14.1 30.5 12.1 26.6 45.6 2.4  6.0 ⋯ 1.6 1.5  4.9 4.7 -1.6
# 15  14   OKC  15 13.9 31.1 12.9 26.1 49.2 1.9  6.0 ⋯ 1.7 1.6  4.7 5.1  3.2
# 16  15   CHI  28 13.9 30.0 12.3 26.0 47.2 1.1  3.1 ⋯ 1.8 1.4  4.3 4.7  0.5
# 17  16   IND  28 13.4 31.0 11.6 23.3 49.6 2.7  6.6 ⋯ 1.9 1.4  3.8 5.8  1.7
# 18  17   SAC   6 13.1 29.7 11.0 22.3 49.3 3.5  7.3 ⋯ 1.0 1.2  5.3 5.8 -4.3
# 19  18   MIL  30 13.0 27.9 10.7 23.1 46.5 2.1  6.7 ⋯ 1.9 1.1  5.4 5.0 -0.9
# 20  19   PHX  10 12.9 28.5 11.7 24.9 47.0 1.4  4.8 ⋯ 1.4 1.1  6.4 5.2 -4.0
# 21  20   SAC   7 12.6 24.7  9.4 21.0 44.9 2.9  7.9 ⋯ 0.9 0.4  4.7 3.4 -5.1
# 22  21   POR  13 12.6 31.2 12.1 24.5 49.4 3.8  8.7 ⋯ 0.9 1.8  5.2 3.4 -0.9
# 23  22   MIA   8 12.5 29.1 11.9 24.6 48.2 2.9  7.5 ⋯ 1.9 1.1  5.4 3.3  2.5
# 24  23   MIA   7 12.5 26.1 10.3 22.0 46.8 3.3  6.3 ⋯ 1.6 1.1  4.0 4.0  1.6
# 25  24   GSW  43 12.4 32.1 12.0 23.0 52.1 3.9  8.9 ⋯ 1.4 0.9  4.0 5.0  6.2
# 26  25   OKC  52 12.1 25.3 10.2 21.6 47.0 1.7  5.7 ⋯ 1.2 1.2  4.6 4.4  0.8
# 27  26   POR  21 12.1 27.5 10.9 21.9 49.6 3.1  7.7 ⋯ 1.9 1.1  4.4 3.9  2.0
# 28  27   POR  19 12.1 27.0 10.7 21.9 48.7 1.9  4.8 ⋯ 1.4 1.4  4.5 4.5  1.2
# 29  28   HOU  42 12.0 31.2 11.0 22.2 49.6 4.3 10.9 ⋯ 0.8 1.3  4.3 5.0  4.6
# 30  29   BOS  36 12.0 27.5 10.7 21.9 48.9 3.6  8.7 ⋯ 1.4 1.4  4.6 3.3  1.6
# ⋮   ⋮    ⋮    ⋮  ⋮    ⋮    ⋮    ⋮    ⋮    ⋮   ⋮    ⋱ ⋮   ⋮    ⋮   ⋮   ⋮
# 221 220  CHA  22 3.6  9.6  3.0  7.0  42.9 1.0 3.0  ⋯ 0.3 0.2  1.5 2.1  1.9
# 222 221  MIA  21 3.6  8.1  2.9  7.0  41.1 0.9 2.4  ⋯ 0.6 0.4  1.5 1.6 -0.3
# 223 222  MIL  21 3.5  7.9  2.9  5.8  49.2 0.7 1.8  ⋯ 0.3 0.2  1.7 1.4 -0.8
# 224 223  DET  32 3.5  7.5  3.0  6.3  47.5 0.4 1.3  ⋯ 0.3 0.4  1.3 1.1 -0.1
# 225 224  PHI  19 3.5  8.3  3.1  6.4  47.5 0.8 1.8  ⋯ 0.6 0.3  1.9 1.4  0.1
# 226 225  MEM  21 3.4  7.5  2.8  6.3  44.4 0.5 2.0  ⋯ 0.3 0.3  1.4 1.4  0.9
# 227 226  MIN  46 3.4  8.4  3.2  6.3  50.3 0.5 1.5  ⋯ 0.1 0.4  1.1 1.7  1.1
# 228 227  CHA  29 3.3  9.1  3.4  5.9  57.6 1.1 2.2  ⋯ 0.2 0.2  1.1 1.1  1.6
# 229 228  BOS  30 3.3  6.2  2.4  5.8  41.1 0.7 2.2  ⋯ 0.2 0.3  1.6 1.2  0.0
# 230 229  CHA  21 3.2  6.4  2.5  5.4  46.0 0.4 1.5  ⋯ 0.6 0.3  1.0 0.9  0.8
# 231 230  MEM  23 3.2  6.7  2.1  4.5  46.6 0.7 2.1  ⋯ 0.3 0.2  1.3 1.7  1.0
# 232 231  LAC  29 3.2  7.6  2.7  5.3  49.7 0.8 1.9  ⋯ 0.3 0.0  1.3 1.6  0.6
# 233 232  SAS  23 3.2  7.3  2.7  5.4  48.8 0.7 1.7  ⋯ 0.4 0.4  1.6 1.5  1.9
# 234 233  MIA  21 3.2  6.2  2.4  5.0  48.1 0.4 1.6  ⋯ 0.3 0.3  1.3 1.4 -0.6
# 235 234  WAS  33 3.1  7.7  3.1  5.7  54.0 0.7 1.7  ⋯ 0.2 0.2  1.3 1.2  0.2
# 236 235  DET  26 3.1  6.7  2.5  5.9  41.6 0.5 1.7  ⋯ 0.2 0.3  1.0 1.4  0.1
# 237 236  MIA  22 3.1  6.1  2.3  5.2  43.9 0.6 2.0  ⋯ 0.4 0.3  1.5 1.1 -0.5
# 238 237  IND  32 3.1  8.3  2.7  5.6  47.8 0.9 2.3  ⋯ 0.3 0.2  1.4 1.8  1.2
# 239 238  IND  27 3.0  7.0  2.6  5.4  48.3 0.7 1.6  ⋯ 0.1 0.3  1.3 1.0  1.1
# 240 239  HOU  23 3.0  7.7  2.6  5.3  48.4 0.7 2.4  ⋯ 0.3 0.4  1.0 1.3  0.2
# 241 240  MEM  22 3.0  6.0  2.1  4.7  44.2 0.5 1.5  ⋯ 0.3 0.3  0.7 1.3  0.5
# 242 241  POR  26 3.0  6.7  2.6  5.0  52.7 0.5 1.4  ⋯ 0.3 0.2  1.0 1.3 -0.1
# 243 242  DET  35 2.9  6.3  2.2  5.4  41.5 0.6 1.5  ⋯ 0.3 0.2  1.3 1.3  0.9
# 244 243  MIN  24 2.9  6.0  2.2  5.0  43.0 0.6 1.6  ⋯ 0.3 0.5  1.8 1.2  0.9
# 245 244  MIA  25 2.9  5.9  2.1  5.1  41.4 0.3 1.3  ⋯ 0.4 0.4  0.8 1.5 -0.5
# 246 245  SAS  30 2.8  6.7  2.3  5.2  44.6 0.7 1.6  ⋯ 0.3 0.3  1.2 1.2 -0.3
# 247 246  LAC  36 2.8  6.0  2.3  4.9  46.9 0.6 1.8  ⋯ 0.4 0.2  1.3 1.1 -0.2
# 248 247  OKC  27 2.7  8.1  2.8  5.3  53.1 0.7 1.7  ⋯ 0.4 0.2  1.0 1.5  2.2
# 249 248  SAS  26 2.7  6.7  2.3  5.1  45.9 0.7 1.8  ⋯ 0.4 0.3  0.7 0.9  0.6
# 250 249  GSW  34 2.3  6.9  2.5  4.4  56.8 0.7 1.4  ⋯ 0.3 0.2  1.0 1.1  0.6
#     First Player    Second Player    Third Player     Fourth Player
# 1   E.Fournier      A.Gordon         E.Payton         T.Ross
# 2   G.Dieng         Z.LaVine         R.Rubio          K.Towns
# 3   B.Beal          M.Gortat         M.Morris         O.Porter
# 4   B.Griffin       D.Jordan         L.Mbah           C.Paul
# 5   K.Irving        L.James          K.Love           J.Smith
# 6   N.Batum         M.Kidd-Gilchrist K.Walker         M.Williams
# 7   E.Bledsoe       D.Booker         T.Chandler       J.Dudley
# 8   G.Dieng         R.Rubio          B.Rush           K.Towns
# 9   K.Irving        L.James          D.Liggins        K.Love
# 10  D.Carroll       D.DeRozan        S.Ibaka          C.Joseph
# 11  A.Aminu         A.Crabbe         M.Harkless       C.McCollum
# 12  L.Deng          T.Mozgov         J.Randle         D.Russell
# 13  D.Cousins       A.Davis          T.Frazier        S.Hill
# 14  C.Anthony       C.Lee            J.Noah           K.Porzingis
# 15  S.Adams         T.Gibson         V.Oladipo        A.Roberson
# 16  J.Butler        T.Gibson         R.Lopez          R.Rondo
# 17  P.George        G.Robinson III   J.Teague         M.Turner
# 18  D.Collison      D.Cousins        R.Gay            G.Temple
# 19  G.Antetokounmpo M.Dellavedova    J.Henson         J.Parker
# 20  D.Booker        M.Chriss         A.Len            T.Ulis
# 21  A.Afflalo       D.Collison       D.Cousins        K.Koufos
# 22  E.Davis         M.Harkless       D.Lillard        C.McCollum
# 23  L.Babbitt       G.Dragic         R.McGruder       J.Richardson
# 24  L.Babbitt       G.Dragic         D.Waiters        H.Whiteside
# 25  S.Curry         K.Durant         D.Green          Z.Pachulia
# 26  S.Adams         V.Oladipo        A.Roberson       D.Sabonis
# 27  A.Aminu         M.Harkless       D.Lillard        C.McCollum
# 28  M.Harkless      D.Lillard        C.McCollum       J.Nurkic
# 29  R.Anderson      T.Ariza          P.Beverley       C.Capela
# 30  A.Bradley       J.Crowder        A.Horford        A.Johnson
# ⋮   ⋮               ⋮                ⋮                ⋮
# 221 N.Batum         M.Belinelli      F.Kaminsky       K.Walker
# 222 G.Dragic        J.Johnson        T.Johnson        D.Waiters
# 223 G.Antetokounmpo M.Dellavedova    K.Middleton      G.Monroe
# 224 K.Caldwell-Pope A.Drummond       T.Harris         J.Leuer
# 225 R.Covington     G.Henderson      E.Ilyasova       T.McConnell
# 226 T.Allen         V.Carter         M.Conley         M.Gasol
# 227 G.Dieng         S.Muhammad       R.Rubio          K.Towns
# 228 N.Batum         M.Belinelli      F.Kaminsky       K.Walker
# 229 J.Brown         J.Jerebko        K.Olynyk         T.Rozier
# 230 M.Belinelli     F.Kaminsky       M.Kidd-Gilchrist K.Walker
# 231 V.Carter        M.Conley         J.Ennis III      M.Gasol
# 232 J.Crawford      B.Griffin        D.Jordan         C.Paul
# 233 D.Dedmon        M.Ginobili       D.Lee            P.Mills
# 234 J.Johnson       T.Johnson        R.McGruder       D.Waiters
# 235 B.Beal          M.Gortat         M.Morris         K.Oubre Jr.
# 236 K.Caldwell-Pope A.Drummond       T.Harris         S.Johnson
# 237 G.Dragic        W.Ellington      J.Johnson        T.Johnson
# 238 M.Ellis         P.George         C.Miles          J.Teague
# 239 L.Allen         M.Ellis          P.George         J.Teague
# 240 T.Ariza         S.Dekker         E.Gordon         J.Harden
# 241 V.Carter        J.Ennis III      M.Gasol          A.Harrison
# 242 A.Crabbe        M.Harkless       D.Lillard        M.Plumlee
# 243 A.Baynes        K.Caldwell-Pope  T.Harris         M.Morris
# 244 N.Bjelica       G.Dieng          K.Dunn           Z.LaVine
# 245 G.Dragic        J.Johnson        T.Johnson        R.McGruder
# 246 L.Aldridge      M.Ginobili       D.Lee            K.Leonard
# 247 J.Crawford      R.Felton         B.Griffin        A.Rivers
# 248 A.Abrines       S.Adams          E.Kanter         A.Roberson
# 249 P.Gasol         M.Ginobili       D.Lee            K.Leonard
# 250 S.Curry         D.Green          A.Iguodala       J.McGee
#     Fifth Player
# 1   N.Vucevic
# 2   A.Wiggins
# 3   J.Wall
# 4   J.Redick
# 5   T.Thompson
# 6   C.Zeller
# 7   T.Warren
# 8   A.Wiggins
# 9   T.Thompson
# 10  J.Valanciunas
# 11  M.Plumlee
# 12  N.Young
# 13  J.Holiday
# 14  D.Rose
# 15  R.Westbrook
# 16  D.Wade
# 17  T.Young
# 18  A.Tolliver
# 19  T.Snell
# 20  T.Warren
# 21  B.McLemore
# 22  M.Plumlee
# 23  H.Whiteside
# 24  J.Winslow
# 25  K.Thompson
# 26  R.Westbrook
# 27  M.Plumlee
# 28  N.Vonleh
# 29  J.Harden
# 30  I.Thomas
# ⋮   ⋮
# 221 M.Williams
# 222 H.Whiteside
# 223 T.Snell
# 224 I.Smith
# 225 N.Noel
# 226 Z.Randolph
# 227 A.Wiggins
# 228 C.Zeller
# 229 M.Smart
# 230 C.Zeller
# 231 J.Green
# 232 A.Rivers
# 233 J.Simmons
# 234 H.Whiteside
# 235 J.Wall
# 236 I.Smith
# 237 H.Whiteside
# 238 M.Turner
# 239 M.Turner
# 240 M.Harrell
# 241 Z.Randolph
# 242 E.Turner
# 243 I.Smith
# 244 S.Muhammad
# 245 H.Whiteside
# 246 P.Mills
# 247 M.Speights
# 248 R.Westbrook
# 249 P.Mills
# 250 K.Thompson

# %%
renamed_lineup_stat <- rename(lineup_stat, "P_M" = "+/-", 
                    "FGP" = "FG%",
                    "3PP" = "3P%", 
                    "FTP" = "FT%")

# %%
final_lineup_stat <- renamed_lineup_stat |>
                 mutate(PIR = PTS + REB + AST + STL + BLK + PFD + FGM - FGA + FTM - FTA - TOV - BLKA - PF) |>
                 mutate(TSP = PTS / ((2 * FGA) + (0.88 * FTA))) |>
                 mutate(PPP = PTS / (FGA + (0.44 * FTA) + TOV)) |>
                 select(PTS, FGP, PIR, TSP, PPP, P_M)
final_lineup_stat
# Out:
#     PTS  FGP  PIR  TSP       PPP       P_M
# 1   52.3 48.2 58.5 0.5658214 1.0171931  0.8
# 2   46.3 47.4 52.5 0.5564904 0.9645833 -0.9
# 3   45.4 49.4 51.5 0.5771382 1.0172074  3.4
# 4   44.0 51.3 56.1 0.6051937 1.0614687  5.4
# 5   40.9 49.0 47.7 0.5975339 1.0589271  2.2
# 6   36.2 45.1 42.5 0.5512914 0.9801798  1.7
# 7   38.3 48.3 37.4 0.5626396 0.9913034  0.1
# 8   34.8 49.5 40.7 0.5776125 1.0021887  0.6
# 9   40.2 52.4 50.7 0.6456379 1.1281994  9.8
# 10  30.4 47.1 34.6 0.5445686 0.9437477  0.4
# 11  31.7 45.4 32.9 0.5516497 0.9453656  0.5
# 12  32.3 46.1 34.5 0.5601415 0.9898259  1.6
# 13  32.0 44.7 38.6 0.5498282 0.9667674  1.7
# 14  30.5 45.6 32.9 0.5295139 0.9413580 -1.6
# 15  31.1 49.2 37.7 0.5443915 0.9434535  3.2
# 16  30.0 47.2 35.9 0.5310862 0.9304057  0.5
# 17  31.0 49.6 38.3 0.5925076 1.0347130  1.7
# 18  29.7 49.3 31.8 0.6039531 1.0140672 -4.3
# 19  27.9 46.5 30.6 0.5410332 0.9527387 -0.9
# 20  28.5 47.0 28.2 0.5266854 0.9060275 -4.0
# 21  24.7 44.9 24.3 0.5436697 0.8785033 -5.1
# 22  31.2 49.4 32.9 0.5920753 1.0631048 -0.9
# 23  29.1 48.2 31.1 0.5519727 1.0118220  2.5
# 24  26.1 46.8 29.4 0.5482272 0.9524157  1.6
# 25  32.1 52.1 42.1 0.6346884 1.0997670  6.2
# 26  25.3 47.0 27.5 0.5334852 0.9162683  0.8
# 27  27.5 49.6 32.5 0.5844101 1.0327475  2.0
# 28  27.0 48.7 29.8 0.5571146 0.9631849  1.2
# 29  31.2 49.6 35.7 0.6236009 1.0979730  4.6
# 30  27.5 48.9 31.0 0.5921619 1.0448328  1.6
# ⋮   ⋮    ⋮    ⋮    ⋮         ⋮         ⋮
# 221 9.6  42.9 10.6 0.5769231 1.0643016  1.9
# 222 8.1  41.1  8.6 0.5139594 0.8920705 -0.3
# 223 7.9  49.2  8.5 0.6032376 1.0466349 -0.8
# 224 7.5  47.5  7.8 0.5320658 0.9436336 -0.1
# 225 8.3  47.5  9.6 0.5841779 0.9876249  0.1
# 226 7.5  44.4  8.4 0.5354083 0.9488866  0.9
# 227 8.4  50.3 10.0 0.5849582 1.0396040  1.1
# 228 9.1  57.6 10.5 0.6982812 1.2438491  1.6
# 229 6.2  41.1  6.1 0.4967949 0.8333333  0.0
# 230 6.4  46.0  7.4 0.5398111 0.9803922  0.8
# 231 6.7  46.6  8.3 0.6226766 1.0668790  1.0
# 232 7.6  49.7  8.4 0.6062540 1.0602679  0.6
# 233 7.3  48.8  8.7 0.5979685 0.9859535  1.9
# 234 6.2  48.1  6.1 0.5393180 0.8673755 -0.6
# 235 7.7  54.0  8.2 0.6181760 1.0366182  0.2
# 236 6.7  41.6  7.3 0.4973278 0.9010221  0.1
# 237 6.1  43.9  6.0 0.5165989 0.8709309 -0.5
# 238 8.3  47.8  8.8 0.6153618 1.1002121  1.2
# 239 7.0  48.3  8.1 0.5817819 1.0580411  1.1
# 240 7.7  48.4  8.9 0.6229773 1.1191860  0.2
# 241 6.0  44.2  7.1 0.5551443 1.0162602  0.5
# 242 6.7  52.7  7.6 0.5873072 1.0145366 -0.1
# 243 6.3  41.5  7.0 0.5236037 0.9380584  0.9
# 244 6.0  43.0  5.8 0.5384063 0.9270705  0.9
# 245 5.9  41.4  6.4 0.5006789 0.9088108 -0.5
# 246 6.7  44.6  7.1 0.5590788 1.0011955 -0.3
# 247 6.0  46.9  6.2 0.5617978 0.9771987 -0.2
# 248 8.1  53.1 10.2 0.6461391 1.1300223  2.2
# 249 6.7  45.9  8.0 0.5860742 1.0442643  0.6
# 250 6.9  56.8  8.9 0.6759404 1.1888353  0.6

# %%
set.seed(96)
lineup_split <- initial_split(final_lineup_stat, prop = 0.75, strata = P_M)
lineup_train <- training(lineup_split)

lineup_train |>
   slice(1:5)

lineup_test <- testing(lineup_split)
# Out:
#   PTS  FGP  PIR  TSP       PPP       P_M
# 1 46.3 47.4 52.5 0.5564904 0.9645833 -0.9
# 2 30.5 45.6 32.9 0.5295139 0.9413580 -1.6
# 3 29.7 49.3 31.8 0.6039531 1.0140672 -4.3
# 4 27.9 46.5 30.6 0.5410332 0.9527387 -0.9
# 5 31.2 49.4 32.9 0.5920753 1.0631048 -0.9

# %%
pts_plot <- ggplot(lineup_train, aes(x = PTS, y = P_M)) + geom_point() +
            xlab("Points") + ylab("Plus Minus") + theme(text = element_text(size=16))

fgp_plot <- ggplot(lineup_train, aes(x = FGP, y = P_M)) + geom_point() +
            xlab("Field Goals Percentage") + ylab("Plus Minus") + theme(text = element_text(size=16))

pir_plot <- ggplot(lineup_train, aes(x = PIR, y = P_M)) + geom_point() +
            xlab("Performance index rating") + ylab("Plus Minus") + theme(text = element_text(size=16))

tsp_plot <- ggplot(lineup_train, aes(x = TSP, y = P_M)) + geom_point() +
            xlab("True Shooting Percentage") + ylab("Plus Minus") + theme(text = element_text(size=16))

ppp_plot <- ggplot(lineup_train, aes(x = PPP, y = P_M)) + geom_point() +
            xlab("Points per possession") + ylab("Plus Minus") + theme(text = element_text(size=16))
pts_plot
fgp_plot
pir_plot
tsp_plot
ppp_plot
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
ggpairs(lineup_train)
# Out:
# plot without title

# %%
lineup_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
      set_engine("kknn") |>
      set_mode("regression") 

lineup_recipe <- recipe(P_M ~ PPP, data = lineup_train) |>
      step_scale(all_predictors()) |>
      step_center(all_predictors())

lineup_vfold <- vfold_cv(lineup_train, v = 5, strata = P_M)

gridvals <- tibble(neighbors = seq(1, 30))

lineup_results <- workflow() |> 
    add_recipe(lineup_recipe) |> 
    add_model(lineup_spec) |>
    tune_grid(resamples = lineup_vfold, grid = gridvals) |> 
    collect_metrics()

# show all the results
lineup_results

# show only the row of minimum RMSPE
lineup_min <- lineup_results |>
   filter(.metric == "rmse") |>
   arrange(mean) |> 
   head(1)

lineup_min


k_min <- lineup_min |>
         pull(neighbors)

lineup_best_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |>
         set_engine("kknn") |>
         set_mode("regression")

lineup_best_fit <- workflow() |>
         add_recipe(lineup_recipe) |>
         add_model(lineup_best_spec) |>
         fit(data = lineup_train)

lineup_summary <- lineup_best_fit |>
          predict(lineup_test) |>
          bind_cols(lineup_test) |>
          metrics(truth = P_M, estimate = .pred)

lineup_summary



lineup_preds <- lineup_best_fit |>
  predict(lineup_train) |>
  bind_cols(lineup_train)

lineup_plot <- ggplot(lineup_preds, aes(x = PPP, y = P_M)) +
  geom_point(alpha = 0.4) +
  labs(x = "Points per possession",
       y = "Plus Minus") +
  geom_line(data = lineup_preds, aes(x = PPP, y = .pred), color = "blue") +
  ggtitle(paste0("K = ", k_min)) +
  theme(text = element_text(size = 20))

lineup_plot
# Out:
#    neighbors .metric .estimator mean      n std_err    .config
# 1   1        rmse    standard   2.0404127 5 0.13284189 Preprocessor1_Model01
# 2   1        rsq     standard   0.2120387 5 0.05127611 Preprocessor1_Model01
# 3   2        rmse    standard   1.8844488 5 0.17159759 Preprocessor1_Model02
# 4   2        rsq     standard   0.2425776 5 0.05427486 Preprocessor1_Model02
# 5   3        rmse    standard   1.7433188 5 0.17546391 Preprocessor1_Model03
# 6   3        rsq     standard   0.2603896 5 0.05533232 Preprocessor1_Model03
# 7   4        rmse    standard   1.7087729 5 0.18957341 Preprocessor1_Model04
# 8   4        rsq     standard   0.2743053 5 0.05639582 Preprocessor1_Model04
# 9   5        rmse    standard   1.7151456 5 0.17674451 Preprocessor1_Model05
# 10  5        rsq     standard   0.2583703 5 0.04444025 Preprocessor1_Model05
# 11  6        rmse    standard   1.6997497 5 0.15918559 Preprocessor1_Model06
# 12  6        rsq     standard   0.2595547 5 0.03720009 Preprocessor1_Model06
# 13  7        rmse    standard   1.6537205 5 0.17086178 Preprocessor1_Model07
# 14  7        rsq     standard   0.2941566 5 0.04352690 Preprocessor1_Model07
# 15  8        rmse    standard   1.6570220 5 0.16627919 Preprocessor1_Model08
# 16  8        rsq     standard   0.2952624 5 0.03846033 Preprocessor1_Model08
# 17  9        rmse    standard   1.6633539 5 0.15981959 Preprocessor1_Model09
# 18  9        rsq     standard   0.2934551 5 0.03823311 Preprocessor1_Model09
# 19 10        rmse    standard   1.6470835 5 0.16329885 Preprocessor1_Model10
# 20 10        rsq     standard   0.3001219 5 0.03690358 Preprocessor1_Model10
# 21 11        rmse    standard   1.6413195 5 0.15215234 Preprocessor1_Model11
# 22 11        rsq     standard   0.2989831 5 0.03185416 Preprocessor1_Model11
# 23 12        rmse    standard   1.6424504 5 0.15168160 Preprocessor1_Model12
# 24 12        rsq     standard   0.2956244 5 0.03163975 Preprocessor1_Model12
# 25 13        rmse    standard   1.6305991 5 0.14800250 Preprocessor1_Model13
# 26 13        rsq     standard   0.3012480 5 0.02747768 Preprocessor1_Model13
# 27 14        rmse    standard   1.6183585 5 0.14734059 Preprocessor1_Model14
# 28 14        rsq     standard   0.3094013 5 0.03112932 Preprocessor1_Model14
# 29 15        rmse    standard   1.6125351 5 0.14714069 Preprocessor1_Model15
# 30 15        rsq     standard   0.3113814 5 0.03088925 Preprocessor1_Model15
# 31 16        rmse    standard   1.6001886 5 0.14663462 Preprocessor1_Model16
# 32 16        rsq     standard   0.3208273 5 0.03256486 Preprocessor1_Model16
# 33 17        rmse    standard   1.5921105 5 0.14556489 Preprocessor1_Model17
# 34 17        rsq     standard   0.3247823 5 0.03137001 Preprocessor1_Model17
# 35 18        rmse    standard   1.5877438 5 0.13898855 Preprocessor1_Model18
# 36 18        rsq     standard   0.3290710 5 0.03692059 Preprocessor1_Model18
# 37 19        rmse    standard   1.5768781 5 0.13735461 Preprocessor1_Model19
# 38 19        rsq     standard   0.3390598 5 0.03702882 Preprocessor1_Model19
# 39 20        rmse    standard   1.5780658 5 0.13927303 Preprocessor1_Model20
# 40 20        rsq     standard   0.3339416 5 0.03421341 Preprocessor1_Model20
# 41 21        rmse    standard   1.5771858 5 0.13480977 Preprocessor1_Model21
# 42 21        rsq     standard   0.3326786 5 0.02528122 Preprocessor1_Model21
# 43 22        rmse    standard   1.5785143 5 0.13684774 Preprocessor1_Model22
# 44 22        rsq     standard   0.3327737 5 0.02459247 Preprocessor1_Model22
# 45 23        rmse    standard   1.5788258 5 0.13712956 Preprocessor1_Model23
# 46 23        rsq     standard   0.3325808 5 0.02507677 Preprocessor1_Model23
# 47 24        rmse    standard   1.5820652 5 0.13735695 Preprocessor1_Model24
# 48 24        rsq     standard   0.3296285 5 0.02464285 Preprocessor1_Model24
# 49 25        rmse    standard   1.5817145 5 0.14033111 Preprocessor1_Model25
# 50 25        rsq     standard   0.3308537 5 0.02502220 Preprocessor1_Model25
# 51 26        rmse    standard   1.5804811 5 0.14210420 Preprocessor1_Model26
# 52 26        rsq     standard   0.3326620 5 0.02473021 Preprocessor1_Model26
# 53 27        rmse    standard   1.5784213 5 0.14152618 Preprocessor1_Model27
# 54 27        rsq     standard   0.3332929 5 0.02548872 Preprocessor1_Model27
# 55 28        rmse    standard   1.5718615 5 0.14111375 Preprocessor1_Model28
# 56 28        rsq     standard   0.3392862 5 0.02775937 Preprocessor1_Model28
# 57 29        rmse    standard   1.5687248 5 0.14159156 Preprocessor1_Model29
# 58 29        rsq     standard   0.3434636 5 0.02540481 Preprocessor1_Model29
# 59 30        rmse    standard   1.5703221 5 0.14160179 Preprocessor1_Model30
# 60 30        rsq     standard   0.3419905 5 0.02637752 Preprocessor1_Model30
#   neighbors .metric .estimator mean     n std_err   .config
# 1 29        rmse    standard   1.568725 5 0.1415916 Preprocessor1_Model29
#   .metric .estimator .estimate
# 1 rmse    standard   1.3266300
# 2 rsq     standard   0.1966416
# 3 mae     standard   1.0213362
# plot without title

# %%
lineup_spec <- linear_reg() |>
  set_engine("lm") |>
  set_mode("regression")

lineup_recipe <- recipe(P_M ~ PPP, data = lineup_train)

lineup_fit <- workflow() |>
  add_recipe(lineup_recipe) |>
  add_model(lineup_spec) |>
  fit(data = lineup_train)
lineup_fit


lineup_test_results <- lineup_fit |>
  predict(lineup_test) |>
  bind_cols(lineup_test) |>
  metrics(truth = P_M, estimate = .pred)

lineup_test_results


# Take this step if you want the RMSPE value.
lineup_rmspe <- lineup_test_results |>
         filter(.metric == "rmse") |>
         select(.estimate) |>
         pull()



lineup_plot_final <- ggplot(lineup_train, aes(x = PPP, y = P_M)) +
  geom_point(alpha = 0.4) +
  xlab("Points per possession") +
  ylab("Plus Minus") +
  geom_smooth(method = "lm", se = FALSE)
lineup_plot_final

coeffs <- lineup_fit |>
             pull_workflow_fit() |>
             tidy()
coeffs
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: linear_reg()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 0 Recipe Steps
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# stats::lm(formula = ..y ~ ., data = data)
#
# Coefficients:
# (Intercept)          PPP
#      -10.97        11.69
#   .metric .estimator .estimate
# 1 rmse    standard   1.3438128
# 2 rsq     standard   0.4028978
# 3 mae     standard   0.9860755
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “`pull_workflow_fit()` was deprecated in workflows 0.2.3.
# Please use `extract_fit_parsnip()` instead.”
#   term        estimate  std.error statistic p.value
# 1 (Intercept) -10.97247 1.415344  -7.752516 5.931493e-13
# 2 PPP          11.68884 1.430132   8.173263 4.728808e-14
# plot without title

# %%
lineup_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
      set_engine("kknn") |>
      set_mode("regression") 

lineup_recipe <- recipe(P_M ~ PPP + TSP, data = lineup_train) |>
      step_scale(all_predictors()) |>
      step_center(all_predictors())

lineup_vfold <- vfold_cv(lineup_train, v = 5, strata = P_M)

gridvals <- tibble(neighbors = seq(1, 30))

lineup_results <- workflow() |> 
    add_recipe(lineup_recipe) |> 
    add_model(lineup_spec) |>
    tune_grid(resamples = lineup_vfold, grid = gridvals) |> 
    collect_metrics()

# show all the results
lineup_results

# show only the row of minimum RMSPE
lineup_min <- lineup_results |>
   filter(.metric == "rmse") |>
   arrange(mean) |> 
   head(1)

lineup_min


k_min <- lineup_min |>
         pull(neighbors)

lineup_best_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |>
         set_engine("kknn") |>
         set_mode("regression")

lineup_best_fit <- workflow() |>
         add_recipe(lineup_recipe) |>
         add_model(lineup_best_spec) |>
         fit(data = lineup_train)

lineup_summary <- lineup_best_fit |>
          predict(lineup_test) |>
          bind_cols(lineup_test) |>
          metrics(truth = P_M, estimate = .pred)

lineup_summary
# Out:
#    neighbors .metric .estimator mean      n std_err    .config
# 1   1        rmse    standard   2.1865752 5 0.12640649 Preprocessor1_Model01
# 2   1        rsq     standard   0.1063945 5 0.02249877 Preprocessor1_Model01
# 3   2        rmse    standard   1.8873272 5 0.14736495 Preprocessor1_Model02
# 4   2        rsq     standard   0.1634352 5 0.04202417 Preprocessor1_Model02
# 5   3        rmse    standard   1.7585966 5 0.12838356 Preprocessor1_Model03
# 6   3        rsq     standard   0.1994885 5 0.04913781 Preprocessor1_Model03
# 7   4        rmse    standard   1.7109520 5 0.11858205 Preprocessor1_Model04
# 8   4        rsq     standard   0.2265812 5 0.05527463 Preprocessor1_Model04
# 9   5        rmse    standard   1.6788286 5 0.14081963 Preprocessor1_Model05
# 10  5        rsq     standard   0.2470032 5 0.07648934 Preprocessor1_Model05
# 11  6        rmse    standard   1.6650411 5 0.13635887 Preprocessor1_Model06
# 12  6        rsq     standard   0.2487900 5 0.07555359 Preprocessor1_Model06
# 13  7        rmse    standard   1.6518797 5 0.13561910 Preprocessor1_Model07
# 14  7        rsq     standard   0.2572863 5 0.07861157 Preprocessor1_Model07
# 15  8        rmse    standard   1.6295985 5 0.12337712 Preprocessor1_Model08
# 16  8        rsq     standard   0.2628965 5 0.06984857 Preprocessor1_Model08
# 17  9        rmse    standard   1.6356420 5 0.10478548 Preprocessor1_Model09
# 18  9        rsq     standard   0.2539050 5 0.05885494 Preprocessor1_Model09
# 19 10        rmse    standard   1.6256070 5 0.11655118 Preprocessor1_Model10
# 20 10        rsq     standard   0.2656058 5 0.06734393 Preprocessor1_Model10
# 21 11        rmse    standard   1.6156212 5 0.12864331 Preprocessor1_Model11
# 22 11        rsq     standard   0.2762691 5 0.07583554 Preprocessor1_Model11
# 23 12        rmse    standard   1.6120513 5 0.13203115 Preprocessor1_Model12
# 24 12        rsq     standard   0.2849808 5 0.08096498 Preprocessor1_Model12
# 25 13        rmse    standard   1.6066708 5 0.13195998 Preprocessor1_Model13
# 26 13        rsq     standard   0.2871894 5 0.08003697 Preprocessor1_Model13
# 27 14        rmse    standard   1.6004971 5 0.13005437 Preprocessor1_Model14
# 28 14        rsq     standard   0.2908698 5 0.07992529 Preprocessor1_Model14
# 29 15        rmse    standard   1.5952454 5 0.13647781 Preprocessor1_Model15
# 30 15        rsq     standard   0.2999677 5 0.08871065 Preprocessor1_Model15
# 31 16        rmse    standard   1.5866133 5 0.13522303 Preprocessor1_Model16
# 32 16        rsq     standard   0.3061241 5 0.08982934 Preprocessor1_Model16
# 33 17        rmse    standard   1.5872033 5 0.13893367 Preprocessor1_Model17
# 34 17        rsq     standard   0.3067187 5 0.09454250 Preprocessor1_Model17
# 35 18        rmse    standard   1.5709620 5 0.13290231 Preprocessor1_Model18
# 36 18        rsq     standard   0.3205346 5 0.09116414 Preprocessor1_Model18
# 37 19        rmse    standard   1.5648032 5 0.12545586 Preprocessor1_Model19
# 38 19        rsq     standard   0.3232964 5 0.08419607 Preprocessor1_Model19
# 39 20        rmse    standard   1.5677322 5 0.12475991 Preprocessor1_Model20
# 40 20        rsq     standard   0.3190240 5 0.08193992 Preprocessor1_Model20
# 41 21        rmse    standard   1.5708474 5 0.12433893 Preprocessor1_Model21
# 42 21        rsq     standard   0.3148855 5 0.07976758 Preprocessor1_Model21
# 43 22        rmse    standard   1.5745157 5 0.12070746 Preprocessor1_Model22
# 44 22        rsq     standard   0.3098188 5 0.07486085 Preprocessor1_Model22
# 45 23        rmse    standard   1.5723397 5 0.12286283 Preprocessor1_Model23
# 46 23        rsq     standard   0.3124909 5 0.07876315 Preprocessor1_Model23
# 47 24        rmse    standard   1.5792209 5 0.11990357 Preprocessor1_Model24
# 48 24        rsq     standard   0.3074718 5 0.07808784 Preprocessor1_Model24
# 49 25        rmse    standard   1.5765028 5 0.11717250 Preprocessor1_Model25
# 50 25        rsq     standard   0.3128183 5 0.07890461 Preprocessor1_Model25
# 51 26        rmse    standard   1.5798340 5 0.11425783 Preprocessor1_Model26
# 52 26        rsq     standard   0.3085412 5 0.07755270 Preprocessor1_Model26
# 53 27        rmse    standard   1.5882157 5 0.11051101 Preprocessor1_Model27
# 54 27        rsq     standard   0.3014064 5 0.07660649 Preprocessor1_Model27
# 55 28        rmse    standard   1.5855295 5 0.11086855 Preprocessor1_Model28
# 56 28        rsq     standard   0.3046314 5 0.07749598 Preprocessor1_Model28
# 57 29        rmse    standard   1.5896696 5 0.10856835 Preprocessor1_Model29
# 58 29        rsq     standard   0.3026458 5 0.07712058 Preprocessor1_Model29
# 59 30        rmse    standard   1.5920618 5 0.11228877 Preprocessor1_Model30
# 60 30        rsq     standard   0.3062054 5 0.08317476 Preprocessor1_Model30
#   neighbors .metric .estimator mean     n std_err   .config
# 1 19        rmse    standard   1.564803 5 0.1254559 Preprocessor1_Model19
#   .metric .estimator .estimate
# 1 rmse    standard   1.3719574
# 2 rsq     standard   0.3678854
# 3 mae     standard   1.0388158

# %%
lineup_spec <- linear_reg() |>
  set_engine("lm") |>
  set_mode("regression")

lineup_recipe <- recipe(P_M ~ PPP + TSP, data = lineup_train)

lineup_fit <- workflow() |>
  add_recipe(lineup_recipe) |>
  add_model(lineup_spec) |>
  fit(data = lineup_train)
lineup_fit


lineup_test_results <- lineup_fit |>
  predict(lineup_test) |>
  bind_cols(lineup_test) |>
  metrics(truth = P_M, estimate = .pred)

lineup_test_results


# Take this step if you want the RMSPE value.
lineup_rmspe <- lineup_test_results |>
         filter(.metric == "rmse") |>
         select(.estimate) |>
         pull()

coeffs <- lineup_fit |>
             pull_workflow_fit() |>
             tidy()
coeffs
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: linear_reg()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 0 Recipe Steps
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# stats::lm(formula = ..y ~ ., data = data)
#
# Coefficients:
# (Intercept)          PPP
#      -10.97        11.69
#   .metric .estimator .estimate
# 1 rmse    standard   1.3438128
# 2 rsq     standard   0.4028978
# 3 mae     standard   0.9860755
# Warning message:
# “`pull_workflow_fit()` was deprecated in workflows 0.2.3.
# Please use `extract_fit_parsnip()` instead.”
#   term        estimate  std.error statistic p.value
# 1 (Intercept) -10.97247 1.415344  -7.752516 5.931493e-13
# 2 PPP          11.68884 1.430132   8.173263 4.728808e-14
